# %% [markdown]
# # GOOGLE

# %% [markdown]
# Now, we will be getting data such as the ski resort's address, ratings, googleid and its opening hours from google.

# %%
import numpy as np
import requests
import json
import googlemaps
import pprint
import time

# %% [markdown]
# We are taking the list of resort names and saving it in googleResorts

# %%
googleResorts = resortNames[:]

# %% [markdown]
# Using google maps api to get the data we need

# %%
api_key = "AIzaSyCySIBN-Du_Gh3WhbVMqhgmFNuIeIvTmSY"
gmaps= googlemaps.Client(key= api_key)

# %% [markdown]
# We will be using resort names to get results from google. Then all the data that we get from google will be saved in an array called final

# %%
resortsInfo=pd.DataFrame()
resorts = googleResorts[:]
final = []
for x in resorts:
    placesResult = gmaps.places(x)
    temp= [x]
    a=placesResult['results']
    temp.extend(a)
    final.append(temp)

# %% [markdown]
# All the elements in the array final, will be saved in googlePlaces

# %%
googlePlaces = final[:]
googlePlaces
# Out:
# [['Squaw Valley USA skiresort',
#   {'formatted_address': '1960 Squaw Valley Rd, Olympic Valley, CA 96146, United States',
#    'geometry': {'location': {'lat': 39.197607, 'lng': -120.2354422},
#     'viewport': {'northeast': {'lat': 39.199548, 'lng': -120.2273822},
#      'southwest': {'lat': 39.1944171, 'lng': -120.2413858}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'b7fb29e66c62c2a21a27cca4b8e183587bc0d74e',
#    'name': 'Squaw Valley Resort',
#    'opening_hours': {},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111337987812849607120">Michael Duarte</a>'],
#      'photo_reference': 'CmRaAAAAhanpdyu08hX07DT76ysT4ArfFK86fZ-ZPx1Er9l_-dNK19ZR8KnRGSu6sYUGuIEiCPjzd6sso-VVNQB9_DNyaL2KybjldERKxqROK8swwwg6FiFwUnQ_K_5tqjUXgS6VEhCKoFVSt2KKuEcn-pePupjaGhSCMiVmqa9K2vabZ5v9wqrHQZEafg',
#      'width': 4032}],
#    'place_id': 'ChIJPSaP8OzZm4ARDxeFl_CIvjA',
# ...

# %%
for i in range(len(googlePlaces)):
    googlePlaces[i] = googlePlaces[i][0:2]

# %% [markdown]
# Putting it into a dataframe named googlePlaces_df

# %%
googlePlaces_df=pd.DataFrame(googlePlaces)
googlePlaces_df
# Out:
#                                             0  \
# 0                  Squaw Valley USA skiresort
# 1                  Mammoth Mountain skiresort
# 2          Heavenly Mountain Resort skiresort
# 3             Mount Shasta Ski Park skiresort
# 4                    Alpine Meadows skiresort
# 5                            Boreal skiresort
# 6                  Donner Ski Ranch skiresort
# 7                          Homewood skiresort
# 8                          Kirkwood skiresort
# 9                Northstar at Tahoe skiresort
# 10                  Sierra-at-Tahoe skiresort
# 11                       Sugar Bowl skiresort
# 12                     Soda Springs skiresort
# 13                     Tahoe Donner skiresort
# 14                      Badger Pass skiresort
# 15                      Bear Valley skiresort
# 16                      Dodge Ridge skiresort
# 17                    June Mountain skiresort
# 18                       China Peak skiresort
# ...

# %% [markdown]
# Since there is missing data about a few resorts, so I will be dropping those rows

# %%
googlePlaces_na=googlePlaces_df.dropna(axis=0, how='any')
googlePlaces_na
# Out:
#                                             0  \
# 0                  Squaw Valley USA skiresort
# 1                  Mammoth Mountain skiresort
# 3             Mount Shasta Ski Park skiresort
# 4                    Alpine Meadows skiresort
# 5                            Boreal skiresort
# 6                  Donner Ski Ranch skiresort
# 7                          Homewood skiresort
# 8                          Kirkwood skiresort
# 9                Northstar at Tahoe skiresort
# 10                  Sierra-at-Tahoe skiresort
# 11                       Sugar Bowl skiresort
# 12                     Soda Springs skiresort
# 13                     Tahoe Donner skiresort
# 14                      Badger Pass skiresort
# 15                      Bear Valley skiresort
# 16                      Dodge Ridge skiresort
# 17                    June Mountain skiresort
# 18                       China Peak skiresort
# 19                      Alta Sierra skiresort
# ...

# %% [markdown]
# In the next steps I will be splitting the data columns that is required and putting into a dataframe

# %%
googlePlaces_ar = np.array(googlePlaces_na)
googlePlaces_list=googlePlaces_ar.tolist()

# %%
for i in range(len(googlePlaces_list)):
    googlePlaces_list[i][1]['google_name'] = googlePlaces_list[i][0]

for i in range(len(googlePlaces_list)):
    googlePlaces_list[i]= googlePlaces_list[i][1]

# %%
googlePlaces_list
# Out:
# [{'formatted_address': '1960 Squaw Valley Rd, Olympic Valley, CA 96146, United States',
#   'geometry': {'location': {'lat': 39.197607, 'lng': -120.2354422},
#    'viewport': {'northeast': {'lat': 39.199548, 'lng': -120.2273822},
#     'southwest': {'lat': 39.1944171, 'lng': -120.2413858}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': 'b7fb29e66c62c2a21a27cca4b8e183587bc0d74e',
#   'name': 'Squaw Valley Resort',
#   'opening_hours': {},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111337987812849607120">Michael Duarte</a>'],
#     'photo_reference': 'CmRaAAAAhanpdyu08hX07DT76ysT4ArfFK86fZ-ZPx1Er9l_-dNK19ZR8KnRGSu6sYUGuIEiCPjzd6sso-VVNQB9_DNyaL2KybjldERKxqROK8swwwg6FiFwUnQ_K_5tqjUXgS6VEhCKoFVSt2KKuEcn-pePupjaGhSCMiVmqa9K2vabZ5v9wqrHQZEafg',
#     'width': 4032}],
#   'place_id': 'ChIJPSaP8OzZm4ARDxeFl_CIvjA',
# ...

# %%
resortsInfo = pd.DataFrame(googlePlaces_list)
resortsInfo
# Out:
#                                     formatted_address  \
# 0   1960 Squaw Valley Rd, Olympic Valley, CA 96146...
# 1   10001 Minaret Rd, Mammoth Lakes, CA 93546, Uni...
# 2   Forest Rte 31, Mt Shasta, CA 96067, United States
# 3   2600 Alpine Meadows Rd, Alpine Meadows, CA 961...
# 4   19749 Boreal Ridge Rd, Soda Springs, CA 95728,...
# 5   19320 Donner Pass Rd, Norden, CA 95724, United...
# 6   60 Loon Mountain Rd, Lincoln, NH 03251, United...
# 7   1501 Kirkwood Meadows Dr, Kirkwood, CA 95646, ...
# 8   5001 Northstar Dr, Truckee, CA 96161, United S...
# 9   1111 Sierra-At-Tahoe Rd, Twin Bridges, CA 9573...
# 10  629 Sugar Bowl Rd, Norden, CA 95724, United St...
# 11  10244 Soda Springs Rd, Soda Springs, CA 95728,...
# 12  11603 Snowpeak Way, Truckee, CA 96161, United ...
# 13  7082 Glacier Point Rd, Yosemite National Park,...
# 14  2280 CA-207, Bear Valley, CA 95223, United States
# 15  1 Dodge Ridge Rd, Pinecrest, CA 95364, United ...
# ...

# %%
resortsInfo['street'] = resortsInfo['formatted_address'].map(lambda x:x.split(',')[0])
resortsInfo['city'] = resortsInfo['formatted_address'].map(lambda x:x.split(',')[-3])
resortsInfo['state&zipcode'] = resortsInfo['formatted_address'].map(lambda x:x.split(',')[-2])
resortsInfo
# Out:
#                                     formatted_address  \
# 0   1960 Squaw Valley Rd, Olympic Valley, CA 96146...
# 1   10001 Minaret Rd, Mammoth Lakes, CA 93546, Uni...
# 2   Forest Rte 31, Mt Shasta, CA 96067, United States
# 3   2600 Alpine Meadows Rd, Alpine Meadows, CA 961...
# 4   19749 Boreal Ridge Rd, Soda Springs, CA 95728,...
# 5   19320 Donner Pass Rd, Norden, CA 95724, United...
# 6   60 Loon Mountain Rd, Lincoln, NH 03251, United...
# 7   1501 Kirkwood Meadows Dr, Kirkwood, CA 95646, ...
# 8   5001 Northstar Dr, Truckee, CA 96161, United S...
# 9   1111 Sierra-At-Tahoe Rd, Twin Bridges, CA 9573...
# 10  629 Sugar Bowl Rd, Norden, CA 95724, United St...
# 11  10244 Soda Springs Rd, Soda Springs, CA 95728,...
# 12  11603 Snowpeak Way, Truckee, CA 96161, United ...
# 13  7082 Glacier Point Rd, Yosemite National Park,...
# 14  2280 CA-207, Bear Valley, CA 95223, United States
# 15  1 Dodge Ridge Rd, Pinecrest, CA 95364, United ...
# ...

# %% [markdown]
# Now from the above data, I will be storing name of the resort, address, opening hours, rating in a list each.

# %%
googlerData = np.array(resortsInfo)
list= googlerData.tolist()

resort_name = list[:]
google_id = list[:]
opening_hours= list[:]
rating= list[:]
street= list[:]
city= list[:]
statezip= list[:]

for i in range(len(resort_name)):
    resort_name[i] = resort_name[i][4]

for i in range(len(google_id)):
    google_id[i] = google_id[i][3]
    
for i in range(len(opening_hours)):
    opening_hours[i] = opening_hours[i][5]
    
for i in range(len(rating)):
    rating[i] = rating[i][9]
    
for i in range(len(street)):
    street[i] = street[i][14]
    
for i in range(len(city)):
    city[i] = city[i][14]
    
for i in range(len(statezip)):
    statezip[i] = statezip[i][14]

# %% [markdown]
# Putting all the data into a dataframe

# %%
google_df = pd.DataFrame({"Resort_Name":resort_name,"Google_Id":google_id,"Opening_Hours":opening_hours,"Google_Rating":rating,"Street":street,"City":city,"State&Zipcode":statezip})
google_df
# Out:
#                             Resort_Name  \
# 0                   Squaw Valley Resort
# 1             Mammoth Mountain Ski Area
# 2              Mt. Shasta Nordic Center
# 3                        Alpine Meadows
# 4            Boreal Mountain California
# 5                      Donner Ski Ranch
# 6                  Loon Mountain Resort
# 7              Kirkwood Mountain Resort
# 8           Northstar California Resort
# 9                Sierra-at-Tahoe Resort
# 10                    Sugar Bowl Resort
# 11         Soda Springs Mountain Resort
# 12     Tahoe Donner Downhill Ski Resort
# 13                 Badger Pass Ski Area
# 14  Skyline Bear Valley Mountain Resort
# 15               Dodge Ridge Ski Resort
# 16               June Mountain Ski Area
# 17           China Peak Mountain Resort
# 18               Alta Sierra Ski Resort
# 19      Buckhorn Ski and Snowboard Club
# 20             Big Bear Mountain Resort
# 21                     Mt. Baldy Resort
# ...

# %% [markdown]
# Saving our data in a csv file

# %%
google_df.to_csv('ski_google.csv',index=False)
